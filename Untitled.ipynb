# %% [markdown]
# # 0. Imports

# %%
import pandas         as pd
import numpy          as np

import seaborn        as sns
from matplotlib            import pyplot as plt
from matplotlib            import gridspec

# %%
def custom_settings():
    # %matplotlib inline
        
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = (20,15)
    plt.rcParams['font.size'] = 10

def format_numbers():
    pd.set_option('display.float_format', lambda x: '%.2f' % x) 
    
custom_settings()
format_numbers()

# %% [markdown]
# # 1. Data collection

# %%
categories = pd.read_csv('data/categories.csv', sep=';')

categories = categories.drop(columns=['picture', 'description'])

# %%
customers = pd.read_csv('data/customers.csv', sep=';')

customers = customers.drop(columns=['contact_name', 'contact_title', 'address', 'region', 'postal_code', 'phone', 'fax'])

customers.columns = ['customer_id', 'customer_name', 'customer_city', 'customer_country']

# %%
employees = pd.read_csv('data/employees.csv', sep=';')

employees['name'] = employees['last_name'] + " " + employees['first_name']

employees = employees.drop(columns=['last_name', 'first_name', 'title_of_courtesy', 'birth_date',
                                    'address','region','postal_code','home_phone','extension','photo','notes',
                                    'reports_to','photo_path'])

employees.columns = ['employee_id', 'employee_title', 'employee_hire_date', 'employee_city', 'employee_country', 'employee_name']

employees = employees[['employee_id', 'employee_name', 'employee_title', 'employee_hire_date', 'employee_city', 'employee_country']]

# %%
orders = pd.read_csv('data/orders.csv', sep=';')

orders = orders.drop(columns=['ship_address','ship_region','ship_postal_code'])

# %%
shippers = pd.read_csv('data/shippers.csv', sep=';')

shippers = shippers.drop(columns=['phone'])

shippers.columns = ['shipper_id', 'shipper_name']

# %%
suppliers = pd.read_csv('data/suppliers.csv', sep=';')

suppliers = suppliers.drop(columns=['address', 'contact_name', 'contact_title', 'region',
                                    'postal_code', 'phone','fax','homepage'])

suppliers.columns = ['supplier_id', 'supplier_name', 'supplier_city', 'supplier_country' ]

# %%
employee_territories = pd.read_csv('data/employee_territories.csv', sep=';')

# %%
order_details = pd.read_csv('data/order_details.csv', sep=';')

order_details.columns = ['order_id', 'product_id', 'order_unit_price', 'quantity', 'discount']

order_details.head()
# Out:
#    order_id  product_id  order_unit_price  quantity  discount
# 0     10248          11             14.00        12      0.00
# 1     10248          42              9.80        10      0.00
# 2     10248          72             34.80         5      0.00
# 3     10249          14             18.60         9      0.00
# 4     10249          51             42.40        40      0.00

# %%
products = pd.read_csv('data/products.csv', sep=';')

products.columns = ['product_id', 'product_name', 'supplier_id', 'category_id', 'quantity_per_unit', 'product_unit_price',
                     'units_in_stock', 'units_on_order', 'reorder_level', 'discontinued' ]

products.head()
# Out:
#    product_id                  product_name  supplier_id  category_id  \
# 0           1                          Chai            8            1
# 1           2                         Chang            1            1
# 2           3                 Aniseed Syrup            1            2
# 3           4  Chef Anton's Cajun Seasoning            2            2
# 4           5        Chef Anton's Gumbo Mix            2            2
#
#      quantity_per_unit  product_unit_price  units_in_stock  units_on_order  \
# 0   10 boxes x 30 bags               18.00              39               0
# 1   24 - 12 oz bottles               19.00              17              40
# 2  12 - 550 ml bottles               10.00              13              70
# 3       48 - 6 oz jars               22.00              53               0
# 4             36 boxes               21.35               0               0
#
#    reorder_level  discontinued
# 0             10             1
# 1             25             1
# 2             25             0
# 3              0             0
# 4              0             1

# %%
region = pd.read_csv('data/region.csv', sep=';')

# %%
territories = pd.read_csv('data/territories.csv', sep=';')

# %% [markdown]
# ## 1.1. Data Merge

# %% [markdown]
# ### 1.1.1. Products

# %%
products = products.merge(suppliers, left_on='supplier_id', right_on='supplier_id')

products = products.merge(categories, left_on='category_id', right_on='category_id')

# %% [markdown]
# ### 1.1.2. Employees

# %%
territories = territories.merge(region, left_on='region_id', right_on='region_id')

employee_territories = employee_territories.merge(territories, left_on='territory_id', right_on='territory_id')

employees = employees.merge(employee_territories, left_on='employee_id', right_on='employee_id')

# %% [markdown]
# ### 1.1.3. Orders Details

# %%
order_details = order_details.merge(products, left_on='product_id', right_on='product_id')

# %% [markdown]
# ### 1.1.4. Orders

# %%
orders = orders.merge(customers, left_on='customer_id', right_on='customer_id')

orders = orders.merge(employees, left_on='employee_id', right_on='employee_id')

orders = orders.merge(order_details, left_on='order_id', right_on='order_id')

# %%
data = orders[['order_id', 'order_date', 'required_date', 'shipped_date', 'ship_via', 'freight', 'ship_name',
'ship_city', 'ship_country', 'order_unit_price', 'quantity', 'discount', 'product_id', 'product_unit_price',
'product_name', 'supplier_id', 'category_id', 'quantity_per_unit',  'units_in_stock','units_on_order',
'reorder_level', 'discontinued', 'supplier_name', 'supplier_city', 'supplier_country', 'category_name',
'customer_id', 'customer_name', 'customer_city', 'customer_country', 'employee_id', 'employee_name', 'employee_title',
'employee_hire_date', 'employee_city','employee_country', 'territory_id', 'territory_description', 'region_id',
'region_description']]

# %% [markdown]
# # 2. Data Description

# %% [markdown]
# ## 2.1. Data Dimension

# %%
print('Number of rows: {}' .format (data.shape[0]))
print('Number of columns: {}' .format (data.shape[1]))
# Out:
# Number of rows: 10129
# Number of columns: 40

# %% [markdown]
# ## 2.2. Data Types

# %%
data.head().T
# Out:
#                                                         0  \
# order_id                                            10248
# order_date                                     1996-07-04
# required_date                                  1996-08-01
# shipped_date                                   1996-07-16
# ship_via                                                3
# freight                                             32.38
# ship_name                       Vins et alcools Chevalier
# ship_city                                           Reims
# ship_country                                       France
# order_unit_price                                    14.00
# quantity                                               12
# discount                                             0.00
# product_id                                             11
# product_unit_price                                  21.00
# product_name                               Queso Cabrales
# supplier_id                                             5
# category_id                                             4
# quantity_per_unit                               1 kg pkg.
# units_in_stock                                         22
# units_on_order                                         30
# reorder_level                                          30
# discontinued                                            0
# supplier_name          Cooperativa de Quesos 'Las Cabras'
# supplier_city                                      Oviedo
# supplier_country                                    Spain
# category_name                              Dairy Products
# customer_id                                         VINET
# customer_name                   Vins et alcools Chevalier
# customer_city                                       Reims
# customer_country                                   France
# employee_id                                             5
# employee_name                             Buchanan Steven
# employee_title                              Sales Manager
# employee_hire_date                             1993-10-17
# employee_city                                      London
# employee_country                                       UK
# territory_id                                         2903
# territory_description                          Providence
# region_id                                               1
# region_description                                Eastern
#
#                                                    1  \
# order_id                                       10248
# order_date                                1996-07-04
# required_date                             1996-08-01
# shipped_date                              1996-07-16
# ship_via                                           3
# freight                                        32.38
# ship_name                  Vins et alcools Chevalier
# ship_city                                      Reims
# ship_country                                  France
# order_unit_price                                9.80
# quantity                                          10
# discount                                        0.00
# product_id                                        42
# product_unit_price                             14.00
# product_name           Singaporean Hokkien Fried Mee
# supplier_id                                       20
# category_id                                        5
# quantity_per_unit                    32 - 1 kg pkgs.
# units_in_stock                                    26
# units_on_order                                     0
# reorder_level                                      0
# discontinued                                       1
# supplier_name                           Leka Trading
# supplier_city                              Singapore
# supplier_country                           Singapore
# category_name                         Grains/Cereals
# customer_id                                    VINET
# customer_name              Vins et alcools Chevalier
# customer_city                                  Reims
# customer_country                              France
# employee_id                                        5
# employee_name                        Buchanan Steven
# employee_title                         Sales Manager
# employee_hire_date                        1993-10-17
# employee_city                                 London
# employee_country                                  UK
# territory_id                                    2903
# territory_description                     Providence
# region_id                                          1
# region_description                           Eastern
#
#                                                2  \
# order_id                                   10248
# order_date                            1996-07-04
# required_date                         1996-08-01
# shipped_date                          1996-07-16
# ship_via                                       3
# freight                                    32.38
# ship_name              Vins et alcools Chevalier
# ship_city                                  Reims
# ship_country                              France
# order_unit_price                           34.80
# quantity                                       5
# discount                                    0.00
# product_id                                    72
# product_unit_price                         34.80
# product_name              Mozzarella di Giovanni
# supplier_id                                   14
# category_id                                    4
# quantity_per_unit               24 - 200 g pkgs.
# units_in_stock                                14
# units_on_order                                 0
# reorder_level                                  0
# discontinued                                   0
# supplier_name            Formaggi Fortini s.r.l.
# supplier_city                            Ravenna
# supplier_country                           Italy
# category_name                     Dairy Products
# customer_id                                VINET
# customer_name          Vins et alcools Chevalier
# customer_city                              Reims
# customer_country                          France
# employee_id                                    5
# employee_name                    Buchanan Steven
# employee_title                     Sales Manager
# employee_hire_date                    1993-10-17
# employee_city                             London
# employee_country                              UK
# territory_id                                2903
# territory_description                 Providence
# region_id                                      1
# region_description                       Eastern
#
#                                                         3  \
# order_id                                            10248
# order_date                                     1996-07-04
# required_date                                  1996-08-01
# shipped_date                                   1996-07-16
# ship_via                                                3
# freight                                             32.38
# ship_name                       Vins et alcools Chevalier
# ship_city                                           Reims
# ship_country                                       France
# order_unit_price                                    14.00
# quantity                                               12
# discount                                             0.00
# product_id                                             11
# product_unit_price                                  21.00
# product_name                               Queso Cabrales
# supplier_id                                             5
# category_id                                             4
# quantity_per_unit                               1 kg pkg.
# units_in_stock                                         22
# units_on_order                                         30
# reorder_level                                          30
# discontinued                                            0
# supplier_name          Cooperativa de Quesos 'Las Cabras'
# supplier_city                                      Oviedo
# supplier_country                                    Spain
# category_name                              Dairy Products
# customer_id                                         VINET
# customer_name                   Vins et alcools Chevalier
# customer_city                                       Reims
# customer_country                                   France
# employee_id                                             5
# employee_name                             Buchanan Steven
# employee_title                              Sales Manager
# employee_hire_date                             1993-10-17
# employee_city                                      London
# employee_country                                       UK
# territory_id                                         7960
# territory_description                          Morristown
# region_id                                               1
# region_description                                Eastern
#
#                                                    4
# order_id                                       10248
# order_date                                1996-07-04
# required_date                             1996-08-01
# shipped_date                              1996-07-16
# ship_via                                           3
# freight                                        32.38
# ship_name                  Vins et alcools Chevalier
# ship_city                                      Reims
# ship_country                                  France
# order_unit_price                                9.80
# quantity                                          10
# discount                                        0.00
# product_id                                        42
# product_unit_price                             14.00
# product_name           Singaporean Hokkien Fried Mee
# supplier_id                                       20
# category_id                                        5
# quantity_per_unit                    32 - 1 kg pkgs.
# units_in_stock                                    26
# units_on_order                                     0
# reorder_level                                      0
# discontinued                                       1
# supplier_name                           Leka Trading
# supplier_city                              Singapore
# supplier_country                           Singapore
# category_name                         Grains/Cereals
# customer_id                                    VINET
# customer_name              Vins et alcools Chevalier
# customer_city                                  Reims
# customer_country                              France
# employee_id                                        5
# employee_name                        Buchanan Steven
# employee_title                         Sales Manager
# employee_hire_date                        1993-10-17
# employee_city                                 London
# employee_country                                  UK
# territory_id                                    7960
# territory_description                     Morristown
# region_id                                          1
# region_description                           Eastern

# %%
#data.dtypes

# %% [markdown]
# ## 2.3. Check NA

# %%
#data.isna().sum()

# %% [markdown]
# ## 2.4. Change variables types

# %%
data['order_date'] = pd.to_datetime(data['order_date'], format='%Y-%m-%d')
data['required_date'] = pd.to_datetime(data['required_date'], format='%Y-%m-%d')
data['shipped_date'] = pd.to_datetime(data['shipped_date'], format='%Y-%m-%d')
data['employee_hire_date'] = pd.to_datetime(data['employee_hire_date'], format='%Y-%m-%d')

# %% [markdown]
# # 3.0 Features Creation

# %%
data['have_discount'] = data[['discount']].apply (lambda x: 0 if(x['discount'] > 0) else 1, axis=1)

# %%
data['total_order'] = data['order_unit_price'] * data['quantity']

# %%
#data['total_order'] = data[['quantity', 'order_unit_price', 'have_discount']].apply (lambda 
#                                                                x: x['order_unit_price'] * x['quantity'] 
#                                                                if x['have_discount'] == 0
#                                                                else x['order_unit_price'] * x['quantity'], axis=1 )

# %%
data['total_order_discount'] = data[['total_order', 'discount', 'have_discount']].apply (lambda 
                                                                x: x['total_order'] - (x['total_order'] * x['discount']) 
                                                                if x['have_discount'] == 0
                                                                else x['total_order'], axis=1)

# %%
data['total_sale'] = data[['order_id','total_order']].groupby('order_id').transform('sum')

# %%
 data['total_sale_discount'] = data[['order_id','total_order_discount']].groupby('order_id').transform('sum')

# %% [markdown]
# # 4.0 Data Exploration

# %%
v_num = data.select_dtypes(include=['int64','float64'])
v_cat = data.select_dtypes(exclude=['int64','float64','datetime64[ns]'])

# %% [markdown]
# ## Variáveis Numéricas

# %%
v_num.hist(bins=20);
sns.set_theme(style ='darkgrid')

# %% [markdown]
# ## Variáveis Categóricas

# %%
print(v_cat.dtypes)
v_cat.head()
# Out:
# ship_name                object
# ship_city                object
# ship_country             object
# product_name             object
# quantity_per_unit        object
# supplier_name            object
# supplier_city            object
# supplier_country         object
# category_name            object
# customer_id              object
# customer_name            object
# customer_city            object
# customer_country         object
# employee_name            object
# employee_title           object
# employee_city            object
# employee_country         object
# territory_description    object
# region_description       object
# dtype: object
#                    ship_name ship_city ship_country  \
# 0  Vins et alcools Chevalier     Reims       France
# 1  Vins et alcools Chevalier     Reims       France
# 2  Vins et alcools Chevalier     Reims       France
# 3  Vins et alcools Chevalier     Reims       France
# 4  Vins et alcools Chevalier     Reims       France
#
#                     product_name quantity_per_unit  \
# 0                 Queso Cabrales         1 kg pkg.
# 1  Singaporean Hokkien Fried Mee   32 - 1 kg pkgs.
# 2         Mozzarella di Giovanni  24 - 200 g pkgs.
# 3                 Queso Cabrales         1 kg pkg.
# 4  Singaporean Hokkien Fried Mee   32 - 1 kg pkgs.
#
#                         supplier_name supplier_city supplier_country  \
# 0  Cooperativa de Quesos 'Las Cabras'        Oviedo            Spain
# 1                        Leka Trading     Singapore        Singapore
# 2             Formaggi Fortini s.r.l.       Ravenna            Italy
# 3  Cooperativa de Quesos 'Las Cabras'        Oviedo            Spain
# 4                        Leka Trading     Singapore        Singapore
#
#     category_name customer_id              customer_name customer_city  \
# 0  Dairy Products       VINET  Vins et alcools Chevalier         Reims
# 1  Grains/Cereals       VINET  Vins et alcools Chevalier         Reims
# 2  Dairy Products       VINET  Vins et alcools Chevalier         Reims
# 3  Dairy Products       VINET  Vins et alcools Chevalier         Reims
# 4  Grains/Cereals       VINET  Vins et alcools Chevalier         Reims
#
#   customer_country    employee_name employee_title employee_city  \
# 0           France  Buchanan Steven  Sales Manager        London
# 1           France  Buchanan Steven  Sales Manager        London
# 2           France  Buchanan Steven  Sales Manager        London
# 3           France  Buchanan Steven  Sales Manager        London
# 4           France  Buchanan Steven  Sales Manager        London
#
#   employee_country territory_description region_description
# 0               UK            Providence            Eastern
# 1               UK            Providence            Eastern
# 2               UK            Providence            Eastern
# 3               UK            Morristown            Eastern
# 4               UK            Morristown            Eastern

# %% [markdown]
# # 5.0 Hypothesis creation

# %% [markdown]
# ### 1- O ticket médio de compras com desconto é menor do que compras sem desconto.
# **Falso:** O ticket médio de compras com desconto é 20.15 % maior.

# %% [markdown]
# #### Comparativo com o preço total

# %%
aux1 = data[data['have_discount']==0][['order_id','total_sale', 'have_discount']].copy()
aux1 = aux1.drop_duplicates(subset='order_id', keep='last')
y_disc = aux1[['have_discount','total_sale']].groupby('have_discount').mean().reset_index()

aux2 = data[data['have_discount']==1][['order_id','total_sale', 'have_discount']].copy()
aux2 = aux2.drop_duplicates(subset='order_id', keep='last')
n_disc = aux2[['have_discount','total_sale']].groupby('have_discount').mean().reset_index()

#aux1[['have_discount']].count()
#aux2[['have_discount']].count()

#width = 0.40
#plt.bar(y_disc['have_discount'], y_disc['total_sale'], width, color='blue')
#plt.bar(n_disc['have_discount'], n_disc['total_sale'], width, color='orange')

# %%
y_disc = aux1[['total_sale']].mean()[0]
n_disc = aux2[['total_sale']].mean()[0]

print('Ticket médio de compras com desconto aplicado: R$ {:,.2f}'.format(y_disc))
print('Ticket médio de compras sem desconto: R$ {:,.2f}'.format(n_disc))

percent = abs( ((y_disc - n_disc) / n_disc)*100 )
print('\nO ticket médio de compras com desconto é', '{:,.2f}'.format(percent),'% maior.')
# Out:
# Ticket médio de compras com desconto aplicado: R$ 9,989.58
# Ticket médio de compras sem desconto: R$ 7,523.42
#
# O ticket médio de compras com desconto é 32.78 % maior.

# %% [markdown]
# #### Comparativo com o desconto aplicado no preço

# %%
aux1 = data[data['have_discount']==0][['order_id','total_sale_discount', 'have_discount']].copy()
aux1 = aux1.drop_duplicates(subset='order_id', keep='last')
y_disc = aux1[['have_discount','total_sale_discount']].groupby('have_discount').mean().reset_index()

aux2 = data[data['have_discount']==1][['order_id','total_sale_discount', 'have_discount']].copy()
aux2 = aux2.drop_duplicates(subset='order_id', keep='last')
n_disc = aux2[['have_discount','total_sale_discount']].groupby('have_discount').mean().reset_index()

#aux1[['have_discount']].count()
#aux2[['have_discount']].count()

#width = 0.40
#plt.bar(y_disc['have_discount'], y_disc['total_sale_discount'], width, color='blue')
#plt.bar(n_disc['have_discount'], n_disc['total_sale_discount'], width, color='orange')

# %%
y_disc = aux1[['total_sale_discount']].mean()[0]
n_disc = aux2[['total_sale_discount']].mean()[0]

print('Ticket médio de compras com desconto aplicado: R$ {:,.2f}'.format(y_disc))
print('Ticket médio de compras sem desconto: R$ {:,.2f}'.format(n_disc))

percent = abs( ((y_disc - n_disc) / n_disc)*100 )
print('\nO ticket médio de compras com desconto é', '{:,.2f}'.format(percent),'% maior.')
# Out:
# Ticket médio de compras com desconto aplicado: R$ 8,692.54
# Ticket médio de compras sem desconto: R$ 7,234.70
#
# O ticket médio de compras com desconto é 20.15 % maior.

# %% [markdown]
# ### 2- Quanto maior o desconto maior o ticket médio
# **Falso:** O ticket médio de compras com desconto é 20.15 % maior.

# %%
aux1 = data[data['have_discount']==0][['order_id','total_sale_discount', 'discount', 'have_discount']].copy()
aux1 = aux1.drop_duplicates(subset='order_id', keep='last')

ticket = aux1[['discount', 'total_sale_discount']].groupby('discount').sum().reset_index()

p = sns.barplot(data=ticket, x='discount', y='total_sale_discount',color='royalblue')
p.set_title('Ticket Médio por desconto aplicado')
p.set_xlabel('Desconto')
p.set_ylabel('Ticket Médio')
# Out:
# Text(0, 0.5, 'Ticket Médio')

# %%
aux1 = data[data['have_discount']==0][['order_id','total_sale_discount', 'discount', 'have_discount']].copy()
aux1 = aux1.drop_duplicates(subset='order_id', keep='last')

ticket = aux1[['discount', 'order_id']].groupby('discount').count().reset_index()

p = sns.barplot(data=ticket, x='discount', y='order_id',color='royalblue')
p.set_title('Número de pedidos por desconto aplicado')
p.set_xlabel('Desconto')
p.set_ylabel('Número de pedidos')
# Out:
# Text(0, 0.5, 'Número de pedidos')
